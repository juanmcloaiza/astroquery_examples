# %% [markdown]
# <hr style="border:2px solid #0281c9"> </hr>
#
# <img align="left" alt="ESO Logo" src="http://archive.eso.org/i/esologo.png">
#
# <div align="center">
#   <h1 style="color: #0281c9; font-weight: bold;">ESO Science Archive</h1>
#   <h2 style="color: #0281c9; font-weight: bold;">Jupyter Notebooks</h2>
# </div>
#
# <hr style="border:2px solid #0281c9"> </hr>

# %% [markdown]
# # **Query by Source Name (position) and Examine Spectral Data as function of time**
#
# This notebook guides users on how to query science-ready spectral databases from ESO, filter the desired observations, and perform cutouts of specific spectral regions before downloading the data. It provides an example science case focusing on creating a spectral sequence for the well-known Beta Pictoris system. The presence of exo-comets is inferred from the stochastic appearances and disappearances of narrow absorption components in gas tracers such as Calcium, caused by the sublimated gas tails of the comets eclipsing our line of sight towards the star.
#
# In addition to querying and downloading data, this notebook also demonstrates how to visualize the spectra and create animated GIFs to illustrate spectral changes over time. The GIFs provide dynamic views of the spectral data, including both cumulative and non-cumulative perspectives, enhancing the analysis of temporal variations.
#
# ---
# **Author**: Catalina Sáez Carvajal (modified by Ashley Thomas Barnes)
# <hr style="border:2px solid #0281c9"> </hr>

# %% [markdown]
# # **Importing and basic usage of astroquery.eso**

# %%
import astroquery # import astroquery
print(f"astroquery version: {astroquery.__version__}") # check the version of astroquery
# Out:
# astroquery version: 0.1.dev10834+gdf50ac37d

# %%
from astroquery.eso import Eso # import the ESO module from astroquery

# %%
eso = Eso() # create an instance of the ESO class

# %%
# Numerical and Data Handling
import numpy as np  # Numerical operations and array handling
import pandas as pd  # Data manipulation and analysis

# Astronomy and Astropy Core
import astropy.units as u  # Physical units and quantities
import astropy.constants as const  # Physical constants (e.g., c, G, h)
from astropy.io import fits  # Reading and writing FITS files
from astropy.coordinates import SkyCoord  # Celestial coordinate handling and transformations
from astropy.time import Time  # Time conversion and formatting (e.g., Julian Date, ISO)

# Visualization
import matplotlib.pyplot as plt  # Core plotting library
from matplotlib.animation import FuncAnimation, PillowWriter  # Animation tools for dynamic plots

# Stop Warnings 
import warnings  # Standard Python module for issuing warnings
warnings.filterwarnings("ignore")  # Ignore all warnings, useful for cleaner output in notebooks or scripts

# %% [markdown]
# The wavelength grid and spectral down-binning used below are implemented with small NumPy helper functions, so this example does not require an additional modeling package.

# %% [markdown]
# # **Performing a Small Cone Search Around Target**

# %% [markdown]
# In this example, we are interested in finding datasets within 5 arcseconds of **Beta Pictoris**, making a cone search particularly useful. You can either use the object's equatorial coordinates directly or employ a name resolver like SESAME (from CDS) to retrieve them. This defines a circular search region characterized by three parameters: right ascension (RA), declination (Dec), and radius, all expressed in degrees.

# %%
star_name = 'Beta Pictoris'
coords_BetaPec = SkyCoord.from_name(star_name)

radius = 5 *u.arcsec # Radius of the search area

# %% [markdown]
# Define the current date and time to get only currently public observations (i.e. with `obs_release_date` later than now).

# %%
now = Time.now() # Get the current time
now = str(now.datetime64.astype('datetime64[s]')) # Convert to datetime64 format

# %% [markdown]
# Now, to look for a given reduced dataset, we perform the cone search intersecting a circle of 5 arcseconds around our target. The query is written in ADQL (Astronomical Data Query Language).
#
# In this query we specify:
# - **Radius (``radius``)**: Filtering of 5 arcsec around position
# - **Spectral Resolving Power (`em_res_power`)**: Filtering datasets with a resolving power greater than 40000.
# - **Data Product Type (`data_types`)**: Filtering for spectral data.
# - **Spectral Bounds (`em_min` and `em_max`)**: Selecting spectra that cover the vacuum wavelength range expressed in meters. Note that here we include the `enclosed=False`, which states the condition will be `em_min < em_min` and `em_max > em_max`.
# - **Signal to Noise Ratio (`snr`)**: Selecting datasets with SNR greater than 300.
# - **Instrument Name (`instrument_name`)**: Restricting the search to objects observed by HARPS.
# - **Top 10 Objects**: Selecting the top 10 objects with the highest SNR.

# %%
table = eso.query_surveys(column_filters={
                                        "instrument_name": "HARPS",
                                        "dataproduct_type": "spectrum",
                                        "em_min": "<3.933643e-07",
                                        "em_max": ">3.933683e-07",
                                        "snr": ">300",
                                        "em_res_power": ">40000", 
                                        "obs_release_date": f"<= '{now}'"},
                        cone_ra=coords_BetaPec.ra.value, 
                        cone_dec=coords_BetaPec.dec.value, 
                        cone_radius=radius.to("deg").value)

# %%
table.sort(['instrument_name', 'dp_id'])
table["target_name", "instrument_name", "proposal_id", "obs_id", "obs_collection", "obstech", "dp_id"][:3]
# Out:
# <Table length=3>
# target_name instrument_name ... obstech            dp_id
#    object        object     ...  object            object
# ----------- --------------- ... ------- ---------------------------
#     HD39060           HARPS ... ECHELLE ADP.2014-09-16T11:03:44.833
#     HD39060           HARPS ... ECHELLE ADP.2014-09-16T11:03:45.750
#     HD39060           HARPS ... ECHELLE ADP.2014-09-16T11:05:09.550

# %% [markdown]
# # **Downloading datasets from the archive**

# %% [markdown]
# **Note**: The following will download a large number of files (~300 at around 5Mb each, so around 1.5Gb in total), and so make take a while.

# %%
data_files = eso.retrieve_data(table['dp_id'], destination='./data/')
# Out:
# INFO: Downloading datasets ... [astroquery.eso.core]
# INFO: Downloading 296 files ... [astroquery.eso.core]
# INFO: Downloading file 1/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-16T11:03:44.833 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-16T11:03:44.833 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-16T11:03:44.833.fits [astroquery.eso.core]
# INFO: Downloading file 2/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-16T11:03:45.750 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-16T11:03:45.750 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-16T11:03:45.750.fits [astroquery.eso.core]
# INFO: Downloading file 3/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-16T11:05:09.550 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-16T11:05:09.550 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-16T11:05:09.550.fits [astroquery.eso.core]
# INFO: Downloading file 4/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-16T11:06:22.077 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-16T11:06:22.077 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-16T11:06:22.077.fits [astroquery.eso.core]
# INFO: Downloading file 5/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12:09:47.350 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-18T12:09:47.350 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-18T12:09:47.350.fits [astroquery.eso.core]
# INFO: Downloading file 6/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12:09:52.027 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-18T12:09:52.027 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-18T12:09:52.027.fits [astroquery.eso.core]
# INFO: Downloading file 7/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12:09:55.643 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-18T12:09:55.643 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-18T12:09:55.643.fits [astroquery.eso.core]
# INFO: Downloading file 8/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12:10:07.263 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-18T12:10:07.263 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-18T12:10:07.263.fits [astroquery.eso.core]
# INFO: Downloading file 9/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12:10:19.833 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-09-18T12:10:19.833 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-09-18T12:10:19.833.fits [astroquery.eso.core]
# INFO: Downloading file 10/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-09-18T12
296 https://dataportal.eso.org/dataPortal/file/ADP.2014-10-07T08:34:29.080 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-10-07T08:34:29.080 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-10-07T08:34:29.080.fits [astroquery.eso.core]
# INFO: Downloading file 95/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-10-07T08:35:05.010 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-10-07T08:35:05.010 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-10-07T08:35:05.010.fits [astroquery.eso.core]
# INFO: Downloading file 96/296 https://dataportal.eso.org/dataPortal/file/ADP.2014-10-07T08:35:51.963 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2014-10-07T08:35:51.963 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2014-10-07T08:35:51.963.fits [astroquery.eso.core]
# INFO: Downloading file 97/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-01-16T01:15:41.423 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-01-16T01:15:41.423 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-01-16T01:15:41.423.fits [astroquery.eso.core]
# INFO: Downloading file 98/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-01-16T01:15:41.709 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-01-16T01:15:41.709 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-01-16T01:15:41.709.fits [astroquery.eso.core]
# INFO: Downloading file 99/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-01-18T01:04:21.171 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-01-18T01:04:21.171 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-01-18T01:04:21.171.fits [astroquery.eso.core]
# INFO: Downloading file 100/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.490 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.490 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.490.fits [astroquery.eso.core]
# INFO: Downloading file 101/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.494 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.494 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.494.fits [astroquery.eso.core]
# INFO: Downloading file 102/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.500 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.500 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.500.fits [astroquery.eso.core]
# INFO: Downloading file 103/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.506 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.506 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.506.fits [astroquery.eso.core]
# INFO: Downloading file 104/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.516 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.516 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.516.fits [astroquery.eso.core]
# INFO: Downloading file 105/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.524 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.524 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.524.fits [astroquery.eso.core]
# INFO: Downloading file 106/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.532 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.532 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.532.fits [astroquery.eso.core]
# INFO: Downloading file 107/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.540 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.540 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.540.fits [astroquery.eso.core]
# INFO: Downloading file 108/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.548 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.548 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.548.fits [astroquery.eso.core]
# INFO: Downloading file 109/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.556 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.556 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.556.fits [astroquery.eso.core]
# INFO: Downloading file 110/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.564 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.564 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.564.fits [astroquery.eso.core]
# INFO: Downloading file 111/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.568 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.568 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.568.fits [astroquery.eso.core]
# INFO: Downloading file 112/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.570 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.570 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.570.fits [astroquery.eso.core]
# INFO: Downloading file 113/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.572 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.572 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.572.fits [astroquery.eso.core]
# INFO: Downloading file 114/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.576 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.576 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.576.fits [astroquery.eso.core]
# INFO: Downloading file 115/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.578 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.578 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.578.fits [astroquery.eso.core]
# INFO: Downloading file 116/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.580 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.580 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.580.fits [astroquery.eso.core]
# INFO: Downloading file 117/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.584 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.584 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.584.fits [astroquery.eso.core]
# INFO: Downloading file 118/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.588 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.588 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.588.fits [astroquery.eso.core]
# INFO: Downloading file 119/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.590 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.590 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.590.fits [astroquery.eso.core]
# INFO: Downloading file 120/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.592 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.592 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.592.fits [astroquery.eso.core]
# INFO: Downloading file 121/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.596 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.596 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.596.fits [astroquery.eso.core]
# INFO: Downloading file 122/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.598 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.598 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.598.fits [astroquery.eso.core]
# INFO: Downloading file 123/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.600 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.600 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.600.fits [astroquery.eso.core]
# INFO: Downloading file 124/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.604 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.604 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.604.fits [astroquery.eso.core]
# INFO: Downloading file 125/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.606 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.606 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.606.fits [astroquery.eso.core]
# INFO: Downloading file 126/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.610 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.610 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.610.fits [astroquery.eso.core]
# INFO: Downloading file 127/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41.612 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2017-04-07T01:04:41.612 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2017-04-07T01:04:41.612.fits [astroquery.eso.core]
# INFO: Downloading file 128/296 https://dataportal.eso.org/dataPortal/file/ADP.2017-04-07T01:04:41
to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.045 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.045.fits [astroquery.eso.core]
# INFO: Downloading file 288/296 https://dataportal.eso.org/dataPortal/file/ADP.2024-04-18T01:01:37.047 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.047 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.047.fits [astroquery.eso.core]
# INFO: Downloading file 289/296 https://dataportal.eso.org/dataPortal/file/ADP.2024-04-18T01:01:37.049 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.049 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.049.fits [astroquery.eso.core]
# INFO: Downloading file 290/296 https://dataportal.eso.org/dataPortal/file/ADP.2024-04-18T01:01:37.051 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.051 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.051.fits [astroquery.eso.core]
# INFO: Downloading file 291/296 https://dataportal.eso.org/dataPortal/file/ADP.2024-04-18T01:01:37.057 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.057 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.057.fits [astroquery.eso.core]
# INFO: Downloading file 292/296 https://dataportal.eso.org/dataPortal/file/ADP.2024-04-18T01:01:37.059 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2024-04-18T01:01:37.059 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2024-04-18T01:01:37.059.fits [astroquery.eso.core]
# INFO: Downloading file 293/296 https://dataportal.eso.org/dataPortal/file/ADP.2025-05-01T01:03:38.125 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2025-05-01T01:03:38.125 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2025-05-01T01:03:38.125.fits [astroquery.eso.core]
# INFO: Downloading file 294/296 https://dataportal.eso.org/dataPortal/file/ADP.2025-05-01T01:03:38.127 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2025-05-01T01:03:38.127 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2025-05-01T01:03:38.127.fits [astroquery.eso.core]
# INFO: Downloading file 295/296 https://dataportal.eso.org/dataPortal/file/ADP.2025-05-01T01:03:38.129 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2025-05-01T01:03:38.129 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2025-05-01T01:03:38.129.fits [astroquery.eso.core]
# INFO: Downloading file 296/296 https://dataportal.eso.org/dataPortal/file/ADP.2025-05-01T01:03:38.131 to /data/jcarmona/astroquery_examples/examples/advanced/data [astroquery.eso.core]
# INFO: Successfully downloaded dataset ADP.2025-05-01T01:03:38.131 to /data/jcarmona/astroquery_examples/examples/advanced/data/ADP.2025-05-01T01:03:38.131.fits [astroquery.eso.core]
# INFO: Done! [astroquery.eso.core]

# %% [markdown]
# ---
# # **Explore the data**

# %% [markdown]
# **Function: Spectra_parameters**
#
# First, we define helper functions for building a wavelength grid and down-binning spectra onto that grid. The `Spectra_parameters` function then calculates the velocity axis using a reference wavelength (`ref`), a spectral resolution (`R`), and a wavelength range (`var`), and saves the velocity data to a CSV file.

# %%
def construct_lam(lammin, lammax, Res=None, dlam=None):
    """Construct a wavelength grid from either resolving power or fixed spacing.

    Parameters:
    lammin (float): Minimum wavelength
    lammax (float): Maximum wavelength
    Res (float, optional): Resolving power, lambda / delta-lambda
    dlam (float, optional): Spectral element width for an evenly spaced grid

    Returns:
    lam (array): Wavelength grid
    dlam (array): Spectral element widths
    """

    if (Res is None and dlam is None) or (Res is not None and dlam is not None):
        raise ValueError("Specify either Res or dlam, but not both.")

    if Res is not None:
        dlam_start = lammin / Res
        dlam_end = lammax / Res

        lam = lammin
        nlam = 1
        while lam < lammax + dlam_end:
            lam += lam / Res
            nlam += 1

        lam = np.zeros(nlam)
        lam[0] = lammin
        for j in range(1, nlam):
            lam[j] = lam[j - 1] + lam[j - 1] / Res

        dlam_grid = np.zeros(nlam)
        for j in range(1, nlam - 1):
            dlam_grid[j] = 0.5 * (lam[j + 1] + lam[j]) - 0.5 * (lam[j - 1] + lam[j])

        dlam_grid[0] = dlam_start
        dlam_grid[-1] = dlam_end

        return lam[:-1], dlam_grid[:-1]

    lam = np.arange(lammin, lammax + dlam, dlam)
    dlam_grid = dlam + np.zeros_like(lam)
    return lam, dlam_grid


def downbin_spec(spec_hr, lam_hr, lam_lr, dlam):
    """Average a high-resolution spectrum into lower-resolution wavelength bins."""

    spec_hr = np.asarray(spec_hr)
    lam_hr = np.asarray(lam_hr)
    lam_lr = np.asarray(lam_lr)
    dlam = np.asarray(dlam)

    if lam_lr.size == 0:
        return np.array([])

    sort_index = np.argsort(lam_hr)
    lam_hr = lam_hr[sort_index]
    spec_hr = spec_hr[sort_index]

    reverse_output = lam_lr[0] > lam_lr[-1]
    if reverse_output:
        lam_lr_work = lam_lr[::-1]
        dlam_work = dlam[::-1]
    else:
        lam_lr_work = lam_lr
        dlam_work = dlam

    bin_edges = np.concatenate((lam_lr_work - 0.5 * dlam_work, [lam_lr_work[-1] + 0.5 * dlam_work[-1]]))
    flux_sum, _ = np.histogram(lam_hr, bins=bin_edges, weights=spec_hr)
    flux_count, _ = np.histogram(lam_hr, bins=bin_edges)

    with np.errstate(divide="ignore", invalid="ignore"):
        spec_lr = flux_sum / flux_count
    spec_lr[flux_count == 0] = np.nan

    if reverse_output:
        spec_lr = spec_lr[::-1]

    return spec_lr


def Spectra_parameters(ref=3933.7, R=115000, var=20):
    """Calculate spectral parameters based on reference wavelength, resolution, and variable range
    
    Parameters:
    ref (float): Reference wavelength in Angstrom (CaII K in air)
    R (int): Spectral resolution
    var (float): Variable range in Angstrom

    Returns:
    wl (array): Wavelength array
    dwl (array): Wavelength step size
    velocity (array): Velocity array
    vel (DataFrame): DataFrame with velocities
    lammin (float): Minimum wavelength
    lammax (float): Maximum wavelength
    """

    # Define the wavelength range around the reference
    lammin = ref - var
    lammax = ref + var
    
    # Construct the wavelength array and wavelength step size
    c = const.c.to("km/s").value # Speed of light in km/s
    wl, dwl = construct_lam(lammin, lammax, Res=R)
    velocity = c * ((wl - ref) / wl) # Calculate the velocity for each wavelength
    vel = pd.DataFrame(data=velocity, columns=["Velocity"]) # Create a DataFrame with the velocities
    vel.to_csv("./data/velocity.csv") # Save the velocity data to a CSV file
    
    return wl, dwl, velocity, vel, lammin, lammax


# Calculate spectral parameters
wl, dwl, velocity, vel, lammin, lammax = Spectra_parameters()

# %% [markdown]
# **Processing FITS Files and Plotting Spectra**
#
# In this section, we process the FITS files that were previously downloaded. For each file, we open it, extract the spectral data from extension 1, normalize the flux, calculate the velocity, and generate a plot of the spectral data.
#
#  The processed data is stored in a DataFrame for further analysis, while observation dates are recorded in a separate DataFrame.

# %%
for i in range(len(data_files)):

    # Construct the full path to the FITS file
    # file_name = f'{output_dir}/{result_from_queries[i]["dp_id"]}_TARGET_{int(em_min_cut*1e9)}-{int(em_max_cut*1e9)}.fits'
    file_name = data_files[i]

    hdulist = fits.open(file_name) # Open the FITS file
    scidata = hdulist[1].data # Bintable extension
    wave = scidata[0][0] # Wavelength data
    flux = scidata[0][1] # Flux data
    contf = flux[np.logical_and(wave > lammin, wave < lammax)] #Select fluxes within the wavelength range
    natwav = wave[np.logical_and(wave > lammin, wave < lammax)] # Select wavelengths within the range
    natf = contf/np.percentile(contf, 95) # Normalize the flux to the 95th percentile
    flr = downbin_spec(natf, natwav, wl, dlam=dwl) # Downsample the spectrum 
    
    # For subsequent iterations (i > 0), add the new flux data to the existing DataFrame df.
    if i==0:
        # If this is the first iteration (i == 0), create a new DataFrame df to store the flux data.
        df = pd.DataFrame(data=flr, columns=[table[i]['dp_id']])
        # Create another DataFrame df2 to store the observation date (MJD) of the file.
        df2 = pd.DataFrame(data=[[table[i]['dp_id'],hdulist[0].header['MJD-OBS']]],columns=['dp_id', 'MJD'])
    
    else:
        # For subsequent iterations (i > 0), add the new flux data to the existing DataFrame df.
        df[table[i]['dp_id']] = flr
        
        # Add the new observation date to the existing DataFrame df2.
        df2.loc[i] = [table[i]['dp_id'], hdulist[0].header['MJD-OBS']]

# %% [markdown]
# ## **Visualizing Spectra with a Static Plot**
#
# To begin, we generate a static plot that displays the normalized flux as a function of velocity for all spectra in our dataset. For clarity, individual spectra are shown in grey, while the mean spectrum is highlighted in red to improve visualization and facilitate comparison.
#
# First, we create a static plot showing the normalized flux versus velocity for all the spectra in our dataset. For clarity, we overlay individual spectra in grey and plot the mean spectrum in red to enhance visualization.

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))

# Loop through each spectrum in the DataFrame df2
for i in range(df2.shape[0]):
    # Plot the normalized flux against velocity for each individual spectrum in grey with some transparency
    ax[0].plot(velocity,df[df2['dp_id'][i]].values, c='grey', alpha=0.1)
    ax[1].plot(velocity,df[df2['dp_id'][i]].values, c='grey', alpha=0.1)

# Plot the mean of all spectra in red with a slightly thicker line and reduced transparency to highlight it

ax[0].plot(velocity,df.mean(axis=1).values, color='C1', lw=2, alpha=0.8)
ax[0].set_xlabel('Velocity (km/s)')
ax[0].set_ylabel('Norm Flux')

ax[1].plot(velocity,df.mean(axis=1).values, color='C1', lw=2, alpha=0.8)
ax[1].set_xlabel('Velocity (km/s)')
ax[1].set_ylabel('Norm Flux')
ax[1].set_xlim(-200,200)
ax[1].set_ylim(-0.03,0.56)

fig.suptitle('CaII K on Beta Pictoris', fontsize=14, fontweight='bold')
fig.tight_layout()
fig.savefig('./figures/BetaPictoris_static.png', transparent=True)

# %% [markdown]
# ## **Visualizing Spectra with a Animated Plot - Cumulative**
#
# We create an animated GIF that visualizes cumulative spectral data over time. This animation allows us to observe how the spectral features evolve as new data is accumulated.

# %%
# Input MJD 
time_mjd = Time(df2['MJD'][0], format='mjd') # Convert MJD to Time object
time_mjd.datetime64.astype('datetime64[s]') # Convert to datetime64 format
# Out:
# np.datetime64('2006-02-09T02:30:17')

# %% [markdown]
# **Note:** The animation uses a significant amount of RAM (>2GB), and may take a while to generate. If you encounter issues, consider reducing the number of spectra or the resolution of the animation. This may also run into issues if you're running this script on e.g. mybinder.org, so you may want to run this locally.

# %%
make_animation = False # Set to True to create the animation, False to skip - may use a lot of RAM

if make_animation:
    print("Creating animation... This may take a while, please be patient.")

    # Create a figure and axis for plotting
    fig, ax = plt.subplots(1, 1, figsize=(6,4))
    # Add small subplot in corner 
    ax_sub = fig.add_axes([0.57, 0.2, 0.3, 0.3]) # [left, bottom, width, height]

    plt.suptitle('CaII K on Beta Pictoris', fontsize=14, fontweight='bold')

    nframes = df.shape[1] # Determine the number of frames based on the number of columns in the DataFrame
    # nframes = 10

    # Function to animate each frame
    def animate(i):

        # Plot the mean values of the DataFrame as a red line
        line, = ax.plot(velocity, df.mean(axis=1).values, color='C1', lw=1, alpha=0.8, ls='--')
        line1, = ax_sub.plot(velocity, df.mean(axis=1).values, color='C1', lw=1, alpha=0.8, ls='--')
        
        # Plot the values of the DataFrame for a specific dp_id as a grey line
        line2, = ax.plot(velocity, df[df2['dp_id'][i]].values, color = 'grey', alpha=0.1)
        line3, = ax_sub.plot(velocity, df[df2['dp_id'][i]].values, color = 'grey', alpha=0.1)

        for txt in ax.texts:
            txt.set_visible(False) # Hide the previous text object
        for txt in ax_sub.texts:
            txt.set_visible(False) # Hide the previous text object

        # Add text annotations for MJD and dp_id
        time_mjd = Time(df2['MJD'][i], format='mjd') # Convert MJD to Time object
        time_mjd = str(time_mjd.datetime64.astype('datetime64[s]')) # Convert to datetime64 format

        ax.text(0.02, 0.15, 'DATE: %s' %time_mjd.split('T')[0], transform=ax.transAxes, fontsize=10, fontweight='bold')
        ax.text(0.02, 0.1, 'TIME: %s' %time_mjd.split('T')[1], transform=ax.transAxes, fontsize=10, fontweight='bold')
        ax.text(0.02, 0.05, 'MJD: %0.2f' %df2["MJD"][i], transform=ax.transAxes, fontsize=10, fontweight='bold')
        
        ax.set_xlabel('Velocity (km/s)')
        ax.set_ylabel('Norm Flux')

        ax.set_xlim(-1200,1500)
        ax.set_ylim(-0.05,1.05)

        ax_sub.set_xlim(-100,140)
        ax_sub.set_ylim(-0.03,0.56)

        return line, line1, line2, line3
            
    # Create the animation object
    ani = FuncAnimation(fig, # The figure to animate
                        animate, # The function to call for each frame
                        interval=4, # Delay between frames in milliseconds
                        blit=True,  # Optimize by only redrawing parts that have changed
                        repeat=True, # Repeat the animation indefinitely
                        frames=range(nframes), # Number of frames in the animation
                        cache_frame_data=False) 
    
    ani.save('./figures/BetaPictoris_faster.gif', dpi=300, writer=PillowWriter(fps=10))
    
else:
    print("Animation creation skipped. Set make_animation to True to create the animation.")
# Out:
# Creating animation... This may take a while, please be patient.

# %% [markdown]
# <hr style="border:2px solid #0281c9"> </hr>
